# %% [markdown]
# <a href="https://colab.research.google.com/github/HariniPandiraju/GEN_AI/blob/main/Gen_AI_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
api_key=userdata.get('GEM_1')

# %%
from google import genai

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Hi, my name is Harini"
)

# %%
interaction
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChcxdzFYYXMyV05wbnhuc0VQZ1pMVG1BMBIXMXcxWGFzMldOcG54bnNFUGdaTFRtQTA', created='2026-07-15T04:34:31Z', updated='2026-07-15T04:34:31Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=8, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=8)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=19, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=217, total_tokens=244, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text="Hi Harini! It's great to meet you. How can I help you today?", type='text', annotations=None)], error=None)], response_format
# ...

# %%
interaction2 = client.interactions.create(
    model="gemini-3.5-flash",
    input="Count letters in my name?",
    previous_interaction_id=interaction.id,
)

# %%
interaction2
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChcxdzFYYXMyV05wbnhuc0VQZ1pMVG1BMBIXTXk1WGF0dkpEZmZQbnNFUDhmLTU0UXc', created='2026-07-15T06:52:35Z', updated='2026-07-15T06:52:35Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=252, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=252)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=39, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=189, total_tokens=480, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text='Your name, **Harini**, has **6** letters! \n\nH-A-R-I-N-I (1-2-3-4-5-6)', type='text', annotations=None)], error=None)], 
# ...
