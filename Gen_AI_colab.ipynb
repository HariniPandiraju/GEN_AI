# %% [markdown]
# <a href="https://colab.research.google.com/github/HariniPandiraju/GEN_AI/blob/main/Gen_AI_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
api_key=userdata.get('GEM_2')

# %%
from google import genai

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Hi, my name is Harini"
)

# %%
interaction
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdIazVYYXI3OE1KU3Q0LUVQdkpxb3NRRRIXSGs1WGFyNzhNSlN0NC1FUHZKcW9zUUU', created='2026-07-15T09:08:46Z', updated='2026-07-15T09:08:46Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=8, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=8)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=19, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=247, total_tokens=274, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text="Hi Harini! It's great to meet you. How can I help you today?", type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text="Hi Harini! It's great to meet you. How can I help you today?", output_image=None, output_audio=None, output_video=None, object='interaction')

# %%
interaction2 = client.interactions.create(
    model="gemini-3.5-flash",
    input="Count letters in my name?",
    previous_interaction_id=interaction.id,
)

# %%
interaction2
# Out:
# Interaction(status='completed', model='gemini-3.5-flash', agent=None, id='v1_ChdIazVYYXI3OE1KU3Q0LUVQdkpxb3NRRRIXUTA1WGFzYkVISTNqanVNUG9idWtvUTg', created='2026-07-15T09:09:23Z', updated='2026-07-15T09:09:23Z', system_instruction=None, tools=None, usage=Usage(total_input_tokens=282, input_tokens_by_modality=[ModalityTokens(modality='text', tokens=282)], total_cached_tokens=0, cached_tokens_by_modality=None, total_output_tokens=44, output_tokens_by_modality=None, total_tool_use_tokens=0, tool_use_tokens_by_modality=None, total_thought_tokens=206, total_tokens=532, grounding_tool_count=None), response_modalities=None, response_mime_type=None, previous_interaction_id=None, environment_id=None, service_tier='standard', webhook_config=None, steps=[ThoughtStep(type='thought', signature='...', summary=None), ModelOutputStep(type='model_output', content=[TextContent(text='Your name, **Harini**, has **6** letters! \n\nHere is the breakdown:\n1. H\n2. a\n3. r\n4. i\n5. n\n6. i', type='text', annotations=None)], error=None)], response_format=None, environment=None, generation_config=None, cached_content=None, agent_config=None, input=None, output_text='Your name, **Harini**, has **6** letters! \n\nHere is the breakdown:\n1. H\n2. a\n3. r\n4. i\n5. n\n6. i', output_image=None, output_audio=None, output_video=None, object='interaction')

# %%
from google.genai import types

response = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='tell me a story on waffle',
    config=types.GenerateContentConfig(


        temperature=0.3,
    ),
)
print(response.text)
# Out:
# In the heart of a bustling kitchen at a diner called *The Cozy Crumb*, a legend was being born.
#
# His name was Barnaby, and he was a waffle.
#
# But Barnaby was not just any waffle. He was the masterpiece of Chef Leo, the diner’s griddle maestro. Barnaby possessed exactly sixty-four perfect, deep-pocketed squares. He was a flawless golden-brown, crispy on the outside, yet light and fluffy on the inside. He smelled of rich butter, sweet vanilla, and a hint of malt.
#
# While most breakfast items were content with just being eaten, Barnaby had a higher calling. He possessed a tiny, warm soul, and his dream was to be the ultimate comfort food. He didn't want to be devoured in a rush by someone scrolling on their phone. He wanted to make a difference.
#
# As he sat on the warming rack, Barnaby watched the dining room.
#
# First, a businessman in a sharp suit sat at the counter. "I'll take a waffle, fast," the man barked.
# Barnaby shuddered. *No, not him,* he thought. *He’ll gulp me down without even tasting the vanilla.* Fortunately, Chef Leo served the businessman a pancake instead.
#
# Next came a group of rowdy teenagers. They were laughing and throwing napkins. *Too chaotic,* Barnaby thought. *They’d probably drown me in ketchup for a dare.*
#
# Then, the bell above the door jingled.
#
# A little girl, about eight years old, walked in holding her mother’s hand. Her shoulders were slumped, and her eyes were fixed on her scuffed red sneakers. Her name was Lily. Her family had just moved to the city that weekend, and tomorrow was her first day at a new school. She was terrified. She didn't know anyone, and the city felt too big, too loud, and too cold.
#
# "How about a special treat to chase away the jitters?" her mother suggested gently.
#
# Lily shrugged, sitting in a booth near the kitchen.
#
# Barnaby felt a spark in his golden crust. *Her,* he thought. *She needs me.*
#
# Chef Leo seemed to sense the magic in the air. He slid Barnaby onto a warm ceramic plate. With the precision of an artist, the chef placed a pat of salted butter right in Barnaby's center squares. Then, he drizzled warm, amber maple syrup over him. The syrup pooled perfectly in Barnaby’s sixty-four pockets, shining like tiny lakes of liquid gold. Finally, a gentle snow of powdered sugar fell over him, topped with a single, crown-like strawberry.
#
# "Here you go, sweetheart," the waitress said, placing the plate in front of Lily. "The Cozy Crumb Special."
#
# Lily looked down. The aroma hit her first—a wave of warm vanilla and caramelized sugar that smelled exactly like her grandmother’s kitchen. For the first time all day, Lily’s shoulders relaxed.
#
# She picked up her fork and knife. Barnaby braced himself, not with fear, but with pride. *This is my moment,* he thought.
#
# *Crunch.*
#
# The sound of the first bite was music to the quiet diner. As the crispy exterior gave way to the fluffy, cloud-like interior, a burst of sweet, buttery warmth filled Lily’s mouth. The saltiness of the butter cut through the sweetness of the syrup in a perfect dance of flavors.
#
# Lily’s eyes widened. She chewed slowly, savoring the warmth.
#
# "Oh," Lily whispered. "Mom, you have to try this. It tastes like... a hug."
#
# "Well," Miss Vandermere murmured, her stern face softening. "I suppose it would be rude to refuse such a handsome waiter."
#
# She took a sample. It was still warm. The exterior was crisp and caramelized from the pearl sugar Arthur folded into the dough, while the inside was light, airy, and smelled of real vanilla and yeast.
#
# Miss Vandermere gasped. The taste took her back to her childhood summers in Brussels. "This," she whispered, "is absolute perfection."
#
# She followed Waffle back to *The Golden Griddle’s* booth. Seeing the famous critic walking with a scruffy dog, the crowd followed.
#
# "Arthur," Miss Vandermere declared, "this waffle is a masterpiece. But why is it so quiet over here?"
#
# Arthur, startled, wiped his hands on his apron. "Well, ma'am, I guess people prefer the sparklers and the neon."
#
# "Sparklers are for the sky; quality is for the plate," she replied firmly.
#
# She wrote her review on the spot, awarding *The Golden Griddle* the coveted "Golden Spoon Award" for the festival. Within minutes, a massive line formed in front of Arthur's booth. Arthur poured batter as fast as the iron could cook, and Waffle stood proudly at his post, greeting every single customer with a wag of his tail.
#
# By the end of the day, they had sold out of every drop of batter. *The Golden Griddle* was saved.
#
# That evening, back in the quiet, warm bakery, Arthur set a special plate on the floor. On it was a dog-friendly waffle, made with sweet potato, a drizzle of peanut butter, and a single crispy bacon strip on top.
#
# "To the best business partner in the world," Arthur smiled, raising his cup of tea.
#
# Waffle didn't hesitate. He polished off his treat, let out a happy, content sigh, and curled up by the warm oven. He closed his eyes, dreaming of sweet butter, maple trees, and the rhythmic, happy sound of his own tail, beating against the floor.

# %%
from google.genai import types

response = client.models.generate_content(
    model='gemini-3.5-flash',
    contents=types.Part.from_text(text='Why the tomato is red?'),
    config=types.GenerateContentConfig(
        temperature=0,
        top_p=1,
        top_k=20,
        candidate_count=1,
        seed=5,
        max_output_tokens=100,
        stop_sequences=['STOP!'],
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)

print(response.text)
# Out:
# Tomatoes are

# %%
user_profile = {
    'properties': {
        'age': {
            'anyOf': [
                {'minimum': 0, 'type': 'integer'},
                {'type': 'null'},
            ],
            'title': 'Age',
        },
        'username': {
            'description': "User's unique name",
            'title': 'Username',
            'type': 'string',
        },
    },
    'required': ['username', 'age'],

}

response = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Give me a random user profile.',
    config={
        'response_mime_type': 'application/json',
        'response_json_schema': user_profile
    },
)
print(response.parsed)
# Out:
# {'id': '7f9a12c4-8e3b-4c2d-9a1b-0e2f3a4b5c6d', 'username': 'johndoe87', 'firstName': 'John', 'lastName': 'Doe', 'email': 'john.doe@example.com', 'avatar': 'https://example.com/avatars/johndoe87.png', 'phoneNumber': '+1-555-0199', 'birthDate': '1987-05-12', 'address': '123 Main Street', 'city': 'Springfield', 'state': 'IL', 'zipCode': '62701', 'country': 'USA', 'isAdmin': False, 'preferences': 'dark', 'notifications': True}
